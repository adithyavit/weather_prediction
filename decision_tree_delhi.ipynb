# %%
import numpy as np

# %%
import pandas as pd

# %%
sdd = pd.read_csv('/Users/adithya/Downloads/machine_learning/ML_LAB/clean_Data_delhi2.csv')

# %%
sdd
# Out:
#          hum conds  tempm  month  pressurem  year  day
# 0       64.0  Haze   18.0     11     1011.0  1996    4
# 1       50.0  Haze   34.0      8     1001.0  2006   25
# 2       53.0  Haze   33.0      8     1003.0  2006   24
# 3       47.0  Haze   35.0      8     1000.0  2006   24
# 4       46.0  Haze   35.0      8      999.0  2006   24
# 5       58.0  Haze   32.0      8     1000.0  2006   24
# 6       75.0  Haze   30.0      8     1002.0  2006   24
# 7       80.0  Haze   30.0      8     1001.0  2006   24
# 8       64.0  Haze   29.0      8     1002.0  2006   25
# 9       66.0  Haze   28.0      8     1004.0  2006   25
# 10      49.0  Haze   32.0      8     1005.0  2006   25
# 11      60.0  Haze   32.0      8     1001.0  2006   25
# 12      78.0  Haze   28.0      8     1002.0  2006   24
# 13      60.0  Haze   30.0      8     1002.0  2006   25
# 14      63.0  Haze   29.0      8     1001.0  2006   25
# 15      68.0  Haze   27.0      8     1001.0  2006   26
# 16      64.0  Haze   28.0      8     1002.0  2006   26
# 17      49.0  Haze   31.0      8     1002.0  2006   26
# 18      43.0  Haze   34.0      8      999.0  2006   26
# 19      45.0  Haze   34.0      8      998.0  2006   26
# 20      51.0  Haze   32.0      8      998.0  2006   26
# 21      54.0  Haze   30.0      8      999.0  2006   26
# 22      72.0  Haze   29.0      8     1002.0  2006   24
# 23      90.0  Haze   28.0      8     1002.0  2006   23
# 24      70.0  Haze   27.0      8      999.0  2006   27
# 25      77.0  Haze   28.0      8     1000.0  2006   22
# 26      75.0  Haze   29.0      8     1001.0  2006   20
# 27      74.0  Haze   28.0      8     1001.0  2006   21
# 28      68.0  Haze   29.0      8     1002.0  2006   21
# 29      52.0  Haze   33.0      8     1002.0  2006   21
# ...      ...   ...    ...    ...        ...   ...  ...
# 49908   93.0   Fog    7.0      1     1016.0  2003   21
# 49909  100.0   Fog    8.0      1     1018.0  2003   21
# 49910  100.0   Fog    6.0      1     1019.0  2003   21
# 49911  100.0   Fog    5.0      1     1019.0  2003   21
# 49912  100.0   Fog    7.0      1     1013.0  1999   30
# 49913  100.0   Fog    7.0      1     1013.0  1999   30
# 49914   87.0   Fog    8.0      2     1022.0  1999    3
# 49915  100.0   Fog    7.0      1     1013.0  1999   30
# 49916   93.0   Fog    6.0      2    -9999.0  1999    3
# 49917   94.0   Fog   11.0      2     1016.0  1999    1
# 49918  100.0   Fog    8.0      2     1016.0  1999    1
# 49919  100.0   Fog    8.0      1     1015.0  1999   31
# 49920  100.0   Fog    9.0      1     1015.0  1999   31
# 49921   94.0   Fog   11.0      1     1016.0  1999   31
# 49922  100.0   Fog    9.0      1     1015.0  1999   31
# 49923  100.0   Fog    8.0      1     1014.0  1999   31
# 49924   77.0   Fog   16.0      1     1012.0  2003   24
# 49925   88.0   Fog   13.0      1     1011.0  2003   24
# 49926   94.0   Fog   10.0      1     1010.0  2003   24
# 49927   94.0   Fog   10.0      1     1009.0  2003   24
# 49928   94.0   Fog   10.0      1     1009.0  2003   23
# 49929   94.0   Fog   11.0      1     1009.0  2003   23
# 49930   94.0   Fog   11.0      1     1010.0  2003   23
# 49931   88.0   Fog   12.0      1     1010.0  2003   23
# 49932   77.0   Fog   14.0      1     1010.0  2003   23
# 49933   77.0   Fog   14.0      1     1011.0  2003   23
# 49934  100.0   Fog    7.0      1     1014.0  1999   31
# 49935  100.0   Fog    7.0      1     1014.0  1999   31
# 49936  100.0   Fog    7.0      1     1013.0  1999   31
# 49937  100.0   Fog    5.0      1     1020.0  2003   19
#
# [49938 rows x 7 columns]

# %%
k1 = sdd[['conds']]

# %%
k11 = k1.values

# %%
k11
# Out:
# array([['Haze'],
#        ['Haze'],
#        ['Haze'],
#        ...,
#        ['Fog'],
#        ['Fog'],
#        ['Fog']], dtype=object)

# %%
k2 = sdd[['tempm']]

# %%
k22 = k2.values

# %%
k22
# Out:
# array([[ 18.],
#        [ 34.],
#        [ 33.],
#        ...,
#        [  7.],
#        [  7.],
#        [  5.]])

# %%
from sklearn.model_selection import train_test_split
X = k22
y = k11
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
sdd.conds.unique()
# Out:
# array(['Haze', 'Fog'], dtype=object)

# %%
feature_names = list(sdd)

# %%
feature_names
# Out:
# ['hum', 'conds', 'tempm', 'month', 'pressurem', 'year', 'day']

# %%
#dataset = sklearn.datasets.base.Bunch(data=examples, target=target)

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
cancer = sdd
X_train, X_test, y_train, y_test = train_test_split(
      k22, k11, stratify=k11, random_state=42)
tree = DecisionTreeClassifier(random_state=0)
tree.fit(X_train, y_train)
print("Accuracy on training set: {:.3f}".format(tree.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(tree.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.982
# Accuracy on test set: 0.981

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file="tree.dot", class_names=["haze", "fog"],
       feature_names=feature_names, impurity=False, filled=True)

# %%
import graphviz
with open("tree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
import numpy as np
import matplotlib.pyplot as plt
def plot_feature_importances_cancer(model):
  n_features = cancer.data.shape[1]
  plt.barh(range(n_features), model.feature_importances_, align='center')
  plt.yticks(np.arange(n_features), cancer.feature_names)
  plt.xlabel("Feature importance")
  plt.ylabel("Feature")

plot_feature_importances_cancer(tree)
